# %% [markdown]
# Exceptions

# %%
try:
    5/0
except:
    print("not accept to david by zero")
# Out:
# not accept to david by zero

# %%
try:
    x = 10
    y = int(input())
    x/y
except:
    print("division by zero")
else:
    print("******")
finally:
    print("done")
# Out:
# ******
# done

# %% [markdown]
# Modules

# %%
    import random
    n = random.random()
    n
# Out:
# 0.6613111069774724

# %%
random.randint(1,10)
# Out:
# 5

# %%
list1 = [1,2,3,4]
random.choices(list1,k=2)
# Out:
# [1, 4]

# %% [markdown]
# Read File

# %%
import os
base = "C:/DEPI/Amit/Src/Python/Session_3/assignments/code"
type(base)
# Out:
# str

# %%
file = os.listdir(base)
print(file)
# Out:
# ['basic.ipynb']

# %%
type(file)
# Out:
# list

# %%
os.remove(base  + '/rem.txt')

# %%
random.choice(file)
# Out:
# 'basic.ipynb'

# %%
base_dir =
file_name =
file_path = os.path.join(base_dir,file_name)

# %%
directory = "C:/DEPI/Amit/Src/Python/Session_3/assignments/code"
if not os.path.exists(directory):
    os.makedirs(directory)
else:
    print("directory exists",directory)

# %%
path = "temp_directory"
if not os.path.exists(path):
    os.makedirs(path)
for i in range (20):
    inner_path = os.path.join(path, "dir_" + str(i))
    if not os.path.exists(inner_path):
        os.makedirs(inner_path)

# %%
with open("./temp_directory/text_1.txt", "a+") as file:
    file.write("New Line added\n")
    file.seek(0)
    updated_content = file.read()
    print(updated_content)
# Out:
# New Line added
# New Line added

# %% [markdown]
# functions

# %%
def std_info(name:str, age:int):
    """
    this function take student information
    param_1 : user name
    type param_1 : str
    param_2 : user age
    type param_2 : int

    return : print student information
    type return : str , int

    """
    return f"my name is {name}, and my age is {age}"

std_info("Ahmed",22)
# Out:
# 'my name is Ahmed, and my age is 22'

# %%
from std import std_info
std_info("Mohamed",20)
# Out:
# 'my name is Mohamed, and my age is 20'

# %%
def func1(*name):
    print(name)
    print(type(name))

# %%
func1("ahmed","alaa","depi","amit")
# Out:
# ('ahmed', 'alaa', 'depi', 'amit')
# <class 'tuple'>

# %%
def func2(**name):
    print(name)
    print(type(name))

# %%
func2(key1 = 10, key2 = 20, key3 = "depi")
# Out:
# {'key1': 10, 'key2': 20, 'key3': 'depi'}
# <class 'dict'>

# %%
def sum(n1,n2):

    return n1+n2

# %%
print((sum(10,20)))
# Out:
# 30

# %%
print(type(sum))
# Out:
# <class 'function'>

# %%
print(type(lambda x : x +10))
# Out:
# <class 'function'>

# %%
result = lambda x : x +10
result(10)
# Out:
# 20

# %%
add = lambda num1 ,num2 : num1 + num2
print(add(10,30))
# Out:
# 40

# %%
def function_1 (n):
    return lambda a : a * 2
function_2 = function_1(2)
print(function_2(11))
# Out:
# 22

# %%
def rev(word):
    words = word.split()
    words.reverse()
    result = " ".join(words)
    return result

# %%
rev("hello world")
# Out:
# 'world hello'
