# %%
x = 5
print("welcome to DEPI",id(x))
# Out:
# welcome to DEPI 140723152618536

# %%
x = 3
type(x)
print(type(x))
str
# Out:
# <class 'int'>
# str

# %%
name = "ahmed "
id = "15"
print(name,id)

'''  
print(name,id)

'''
# Out:
# ahmed  15
# '  \nprint(name,id)\n\n'

# %%
x = 20
y = 30
print("value of x =",x," and value of y = ",y )
print("this is x {} and y {} ".format(x,y))
print(f"this is x = {x}  and y = {y}")
# Out:
# value of x = 20  and value of y =  30
# this is x 20 and y 30
# this is x = 20  and y = 30

# %%
name = "ahmed morad"
course_name = " machine learning"
id = "15"
print(f"student name is {name} , course name is {course_name} , and id is {id}")
# Out:
# student name is ahmed morad , course name is  machine learning , and id is 15

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %%
name = "DEPI R4"
name[0]
name[:4:1]
# Out:
# 'DEPI'

# %%
name = "welcone into depi r4"
upper = name.upper()
print(upper)
lower = upper.lower()
print(lower)
replace = lower.replace("into","to")
print(replace)
captale = name.capitalize()
print(captale)
# Out:
# WELCONE INTO DEPI R4
# welcone into depi r4
# welcone to depi r4
# Welcone into depi r4

# %%
name = "welcone into depi r4"
tittle = name.title()
print(tittle)
count = name.count("r4")
print(count)
split = name.split()
print(split)
print(type(split))
sent = '  '.join(split)
print(type(sent))
sent.startswith("Welcome")
# Out:
# Welcone Into Depi R4
# 1
# ['welcone', 'into', 'depi', 'r4']
# <class 'list'>
# <class 'str'>
# False

# %%
name = "welcone into \ndepi r4"
print(name)
name = "welcone into \tdepi r4"
print(name)
name = "welcone into \bdepi r4"
print(name)
name = "welcone \"into\" depi r4"
print(name)
# Out:
# welcone into
# depi r4
# welcone into 	depi r4
# welcone intodepi r4
# welcone "into" depi r4

# %%
L = [1,2,3]
type(L)
# Out:
# list

# %%
T = (1,2,3)
print(type(T))
T2 = "ahmed"
tuple(T2)
# Out:
# <class 'tuple'>
# ('a', 'h', 'm', 'e', 'd')
