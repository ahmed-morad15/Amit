# %%
list_1 = [1,2,3,"depi","learning",True,[1,2,3,True,["ds","ml","genai"]]]
list_1[6][4][2]
# Out:
# 'genai'

# %%
list_2 = [1,2,3,4]
list_3 = [5,6,7,8]
list_2.append("one")
list_2
# Out:
# [1, 2, 3, 4, 'one']

# %%
list_2.insert(0,"AMIT")
list_2
# Out:
# ['AMIT', 1, 2, 3, 4, 'one']

# %%
list_2 + list_3
# Out:
# ['AMIT', 1, 2, 3, 4, 'one', 5, 6, 7, 8]

# %%
list_2.extend(list_3)
list_2
# Out:
# ['AMIT', 1, 2, 3, 4, 'one', 5, 6, 7, 8]

# %%
list_4 = [1,2,3,4,"depi"]
list_4.remove("depi")
list_4
# Out:
# [1, 2, 3, 4]

# %%
list_4.pop()
list_4
# Out:
# [1, 2, 3]

# %%
list_4.pop(0)
list_4
# Out:
# [2, 3]

# %%
del list_4[0]
list_4
# Out:
# [3]

# %%
name = input("enter your name")
id = input("enter your id")
print(f"your name is {name}, and your id is {id}")
# Out:
# your name is Ahmed, and your id is 15

# %%
input_list = ["amit","learning","python","ml"]
item = input()
input_list.remove(item)
input_list
# Out:
# ['amit', 'learning', 'python']

# %%
list_5 = [1,2,2,3,4,5]
list_5.index(2)
# Out:
# 1

# %%
list_5.count(2)
# Out:
# 2

# %%
list_6 = [20,50,10,30,5]
list_6.sort()
list_6
# Out:
# [5, 10, 20, 30, 50]

# %%
tuple_1 = (1,2,3,4)
tuple_1
# Out:
# (1, 2, 3, 4)

# %%
set_1 = {1,2,3}
set_2 = {3,4,5}
print(set_1.intersection(set_2))
print(set_1.union(set_2))
print(set_1.difference(set_2))
# Out:
# {3}
# {1, 2, 3, 4, 5}
# {1, 2}

# %%
dic_1 = {"key_1" : 12.5 , "key_2" : "depi"}
dic_1["key_1"]
# Out:
# 12.5

# %%
items = [('a',1),('b',2),('c',3)]
new_dic = dict(items)
new_dic
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
num_1 = int(input("enter number 1"))
num_2 = int(input("enter number 2"))
#operation = input("enter your operation ")
print(f"sum of numbers is {num_1 + num_2}")
print(f"sub of numbers is {num_1 - num_2}")
print(f"mul of numbers is {num_1 * num_2}")
print(f"dev of numbers is {num_1 / num_2}")
# Out:
# sum of numbers is 25
# sub of numbers is 15
# mul of numbers is 100
# dev of numbers is 4.0

# %%
a = 20
b = 10
if a < b:
    print("b is bigger")
elif a == b:
    print(" two are equal")
else:
    print("a is bigger")
# Out:
# a is bigger

# %%
x = 10
res = "even" if x % 2 == 0 else "odd"
print(res)
# Out:
# even

# %%
a = 10
b = 5
result = a+b if a>b else a-b
print(result)
# Out:
# 15

# %%
age = 21
print("adult") if age >18 else print("tennager") if age >=13 else print("child")
# Out:
# adult

# %%
is_sunny = True
temp = 25
if is_sunny:
    print("its a sunny day")
    if temp >20:
        print("weather is warm")
    else:
        print("weather is cool")
else:
    print("its not sunny day")
# Out:
# its a sunny day
# weather is warm

# %%
deg = int(input("enter degree"))
if deg >0 and deg <=100:
    if deg >=90 and deg <=100:
        print("A")
    elif deg >=80 and deg <90  :
        print("B")
    elif deg >=70 and deg <80  :
        print("C")
    elif deg >=60 and deg <70  :
        print("D")
    else:
        print("F")

else:
    print("invalled")
# Out:
# A

# %%
for x in range (5):
    if x == 3:
        continue
    print(x)
# Out:
# 0
# 1
# 2
# 4

# %%
for x in range (5):
    if x == 3:
        break
    print(x)
# Out:
# 0
# 1
# 2

# %%
for x in range (5):
    if x == 2:
        pass
    else:
        print(x)
# Out:
# 0
# 1
# 3
# 4

# %%
x = 0
while x <= 5:
    print(x)
    x +=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
