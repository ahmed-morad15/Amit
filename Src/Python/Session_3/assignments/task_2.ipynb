# %%
import os
import random

def thanos_project(folder_path, num_files):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Folder created: {folder_path}")
    else:
        print(f"Folder already exists: {folder_path}")

    for i in range(1, num_files + 1):
        file_path = os.path.join(folder_path, f"file_{i}.txt")
        with open(file_path, "w") as f:
            f.write(f"This is file {i}\n")
    print(f"{num_files} files created.")

    files = os.listdir(folder_path)
    print(f"Number of files before Thanos snap: {len(files)}")

    half_count = len(files) // 2
    files_to_delete = random.sample(files, half_count)
    for f in files_to_delete:
        os.remove(os.path.join(folder_path, f))
    print(f"{half_count} files randomly deleted.")

    remaining_files = os.listdir(folder_path)
    print(f"Number of files after Thanos snap: {len(remaining_files)}")
    print("Remaining files:", remaining_files)


folder = "thanos_folder"
num_files_to_create = 10

thanos_project(folder, num_files_to_create)
# Out:
# Folder created: thanos_folder
# 10 files created.
# Number of files before Thanos snap: 10
# 5 files randomly deleted.
# Number of files after Thanos snap: 5
# Remaining files: ['file_1.txt', 'file_10.txt', 'file_2.txt', 'file_7.txt', 'file_9.txt']
